# %%
import numpy as np

np.random.randn(200, 3)
# Out:
# array([[ 0.51757768,  0.83899016,  0.1900441 ],
#        [-0.43014163,  1.25405978,  0.68230294],
#        [-1.24570263,  1.1558163 , -0.83686645],
#        [ 0.16709338,  0.61358419, -1.14347963],
#        [-0.09171411,  0.49563667, -0.82281834],
#        [ 0.71827113, -0.89705051, -2.3600922 ],
#        [-0.75938258, -0.14976856,  0.66822116],
#        [ 1.37806827,  0.18551027, -1.26335084],
#        [ 0.40034411, -1.81784177,  0.2391258 ],
#        [-1.66127225,  0.69744956, -1.50067702],
#        [-0.87352038, -1.95225001, -0.15882775],
#        [ 0.73100256,  0.59513106,  1.75984403],
#        [ 0.225054  , -1.32106302, -0.34006864],
#        [ 0.54384179,  1.3110826 , -0.60014954],
#        [ 0.7196095 , -1.49494107,  0.11864976],
#        [ 0.68893124,  0.38143182,  1.36643845],
#        [ 0.49958304,  1.34752267, -0.14646952],
#        [-1.02215095,  0.56200778, -1.05094217],
#        [-0.61346769,  0.00915258, -0.87412016],
#        [ 0.26908494, -0.18619882,  0.56040101],
# ...
